# %% [markdown]
# # FEDeRATED Data Sharing

# %% [markdown]
# ### Dependency Syncronization

# %% [markdown]
# ##### Downloading Libraries

# %%
import sys

# Installing numpy
# !{sys.executable} -m pip install numpy

# Installing pandas
# !{sys.executable} -m pip install pandas

# Installing matplotlib
# !{sys.executable} -m pip install matplotlib

#Installing tqdm
# !{sys.executable} -m pip install tqdm
# Out:
# Requirement already satisfied: numpy in c:\python312\lib\site-packages (1.26.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\python312\lib\site-packages (2.1.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\python312\lib\site-packages (from pandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pc\appdata\roaming\python\python312\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python312\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\python312\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\pc\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\python312\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python312\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python312\lib\site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\python312\lib\site-packages (from matplotlib) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\pc\appdata\roaming\python\python312\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\python312\lib\site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python312\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pc\appdata\roaming\python\python312\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\pc\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tqdm in c:\python312\lib\site-packages (4.66.1)
# Requirement already satisfied: colorama in c:\users\pc\appdata\roaming\python\python312\site-packages (from tqdm) (0.4.6)
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ##### Importing Packages

# %%
# Import Native Libraries
from __future__             import annotations
# Import Statistic Libraries
import numpy                as np
import pandas               as pd
import matplotlib.pyplot    as plt

# Import Utility Libraries
from typing                 import List, Dict
from random                 import choice, random, uniform
from time                   import sleep, time
from tqdm                   import tqdm
from uuid                   import uuid4
from pprint                 import PrettyPrinter

# %% [markdown]
# ### Simulation Definition

# %% [markdown]
# ##### Defining Settings

# %%
settings : Dict[str, Dict[str, list]] = {
    "test": {
        "delay": [0.0623, 0.2585, 0.2238, 0.1017, 0.1276, 0.1784, 0.2742, 0.0865, 0.2951, 0.1953, 0.1379, 0.2407, 0.2814, 0.0792, 0.2079, 0.0334, 0.2646, 0.1551, 0.1687, 0.1158, 0.2923, 0.0491, 0.0483, 0.1937, 0.1769, 0.0687, 0.2799, 0.0962, 0.0649, 0.1206, 0.2624, 0.2910, 0.2105, 0.0703, 0.1508, 0.1326, 0.0420, 0.1564, 0.0523, 0.2379, 0.2849, 0.0850, 0.1841, 0.2148, 0.1986, 0.1080, 0.1968, 0.2271, 0.1736, 0.2264, 0.2318, 0.2589, 0.0769, 0.1436, 0.2916, 0.2082, 0.1828, 0.0896, 0.2480, 0.1866, 0.2363, 0.1616, 0.1847, 0.0503, 0.0584, 0.1064, 0.2280, 0.1586, 0.1636, 0.2557, 0.1175, 0.2690, 0.2249, 0.2658, 0.0698, 0.2257, 0.1611, 0.0554, 0.1464, 0.1236, 0.0754, 0.2195, 0.1030, 0.0941, 0.1789, 0.0912, 0.1300, 0.1357, 0.0890, 0.1321, 0.0761, 0.1052, 0.2538, 0.0377, 0.0874, 0.1216, 0.0668, 0.2142, 0.0736, 0.1406, 0.1667, 0.1594, 0.1445, 0.2749, 0.2213, 0.1682, 0.1744, 0.2596, 0.1023, 0.2189, 0.0690, 0.1469, 0.1010, 0.1821, 0.2639, 0.0815],
        "clients": [30, 50, 70],
        "request_size": [908.37, 1362.41, 1378.55, 1216.62, 1397.12, 1080.28, 1347.66, 771.84, 1210.19, 1132.47, 1121.89, 727.93, 1252.64, 1270.73, 1229.83, 681.42, 1336.58, 1220.45, 618.25, 1066.06, 614.17, 1087.92, 1129.98, 1291.54, 1142.19, 795.73, 1137.28, 1144.31, 1420.39, 798.51, 1074.12, 1403.45, 1092.63, 1071.97, 1234.51, 1251.37, 1230.16, 731.79, 991.47, 1256.16, 749.84],
        "table_amount": 20,
        "cycles": 10,
        "requests": 10,
        "subscriptions": [100, 150, 200]
    },
    "small": {
        "delay": [0.0623, 0.2585, 0.2238, 0.1017, 0.1276, 0.1784, 0.2742, 0.0865, 0.2951, 0.1953, 0.1379, 0.2407, 0.2814, 0.0792, 0.2079, 0.0334, 0.2646, 0.1551, 0.1687, 0.1158, 0.2923, 0.0491, 0.0483, 0.1937, 0.1769, 0.0687, 0.2799, 0.0962, 0.0649, 0.1206, 0.2624, 0.2910, 0.2105, 0.0703, 0.1508, 0.1326, 0.0420, 0.1564, 0.0523, 0.2379, 0.2849, 0.0850, 0.1841, 0.2148, 0.1986, 0.1080, 0.1968, 0.2271, 0.1736, 0.2264, 0.2318, 0.2589, 0.0769, 0.1436, 0.2916, 0.2082, 0.1828, 0.0896, 0.2480, 0.1866, 0.2363, 0.1616, 0.1847, 0.0503, 0.0584, 0.1064, 0.2280, 0.1586, 0.1636, 0.2557, 0.1175, 0.2690, 0.2249, 0.2658, 0.0698, 0.2257, 0.1611, 0.0554, 0.1464, 0.1236, 0.0754, 0.2195, 0.1030, 0.0941, 0.1789, 0.0912, 0.1300, 0.1357, 0.0890, 0.1321, 0.0761, 0.1052, 0.2538, 0.0377, 0.0874, 0.1216, 0.0668, 0.2142, 0.0736, 0.1406, 0.1667, 0.1594, 0.1445, 0.2749, 0.2213, 0.1682, 0.1744, 0.2596, 0.1023, 0.2189, 0.0690, 0.1469, 0.1010, 0.1821, 0.2639, 0.0815],
        "clients": [70, 100, 130],
        "request_size": [908.37, 1362.41, 1378.55, 1216.62, 1397.12, 1080.28, 1347.66, 771.84, 1210.19, 1132.47, 1121.89, 727.93, 1252.64, 1270.73, 1229.83, 681.42, 1336.58, 1220.45, 618.25, 1066.06, 614.17, 1087.92, 1129.98, 1291.54, 1142.19, 795.73, 1137.28, 1144.31, 1420.39, 798.51, 1074.12, 1403.45, 1092.63, 1071.97, 1234.51, 1251.37, 1230.16, 731.79, 991.47, 1256.16, 749.84],
        "table_amount": 20,
        "cycles": 30,
        "requests": 100,
        "subscriptions": [210, 450, 700]
    },
    "medium": {
        "delay": [0.0623, 0.2585, 0.2238, 0.1017, 0.1276, 0.1784, 0.2742, 0.0865, 0.2951, 0.1953, 0.1379, 0.2407, 0.2814, 0.0792, 0.2079, 0.0334, 0.2646, 0.1551, 0.1687, 0.1158, 0.2923, 0.0491, 0.0483, 0.1937, 0.1769, 0.0687, 0.2799, 0.0962, 0.0649, 0.1206, 0.2624, 0.2910, 0.2105, 0.0703, 0.1508, 0.1326, 0.0420, 0.1564, 0.0523, 0.2379, 0.2849, 0.0850, 0.1841, 0.2148, 0.1986, 0.1080, 0.1968, 0.2271, 0.1736, 0.2264, 0.2318, 0.2589, 0.0769, 0.1436, 0.2916, 0.2082, 0.1828, 0.0896, 0.2480, 0.1866, 0.2363, 0.1616, 0.1847, 0.0503, 0.0584, 0.1064, 0.2280, 0.1586, 0.1636, 0.2557, 0.1175, 0.2690, 0.2249, 0.2658, 0.0698, 0.2257, 0.1611, 0.0554, 0.1464, 0.1236, 0.0754, 0.2195, 0.1030, 0.0941, 0.1789, 0.0912, 0.1300, 0.1357, 0.0890, 0.1321, 0.0761, 0.1052, 0.2538, 0.0377, 0.0874, 0.1216, 0.0668, 0.2142, 0.0736, 0.1406, 0.1667, 0.1594, 0.1445, 0.2749, 0.2213, 0.1682, 0.1744, 0.2596, 0.1023, 0.2189, 0.0690, 0.1469, 0.1010, 0.1821, 0.2639, 0.0815],
        "clients": [160, 190, 220],
        "request_size": [1372.54, 1512.23, 1261.89, 1639.67, 1155.12, 1212.45, 1689.34, 1445.76, 1399.88, 1089.23, 1577.43, 1755.69, 1345.98, 1234.76, 1650.32, 1123.56, 1498.45, 1750.12, 1023.89, 1289.76, 1756.23, 1199.45, 1323.67, 1545.21, 1687.99, 1290.34, 1376.65, 1467.34, 1611.78, 1712.56, 1211.99, 1122.34, 1423.78, 1544.23, 1665.45, 1734.56, 1089.12, 1512.67, 1311.45, 1789.56, 1066.23],
        "table_amount": 20,
        "cycles": 50,
        "requests": 300,
        "subscriptions": [400, 600, 800]

    },
    "large": {
        "delay": [0.0623, 0.2585, 0.2238, 0.1017, 0.1276, 0.1784, 0.2742, 0.0865, 0.2951, 0.1953, 0.1379, 0.2407, 0.2814, 0.0792, 0.2079, 0.0334, 0.2646, 0.1551, 0.1687, 0.1158, 0.2923, 0.0491, 0.0483, 0.1937, 0.1769, 0.0687, 0.2799, 0.0962, 0.0649, 0.1206, 0.2624, 0.2910, 0.2105, 0.0703, 0.1508, 0.1326, 0.0420, 0.1564, 0.0523, 0.2379, 0.2849, 0.0850, 0.1841, 0.2148, 0.1986, 0.1080, 0.1968, 0.2271, 0.1736, 0.2264, 0.2318, 0.2589, 0.0769, 0.1436, 0.2916, 0.2082, 0.1828, 0.0896, 0.2480, 0.1866, 0.2363, 0.1616, 0.1847, 0.0503, 0.0584, 0.1064, 0.2280, 0.1586, 0.1636, 0.2557, 0.1175, 0.2690, 0.2249, 0.2658, 0.0698, 0.2257, 0.1611, 0.0554, 0.1464, 0.1236, 0.0754, 0.2195, 0.1030, 0.0941, 0.1789, 0.0912, 0.1300, 0.1357, 0.0890, 0.1321, 0.0761, 0.1052, 0.2538, 0.0377, 0.0874, 0.1216, 0.0668, 0.2142, 0.0736, 0.1406, 0.1667, 0.1594, 0.1445, 0.2749, 0.2213, 0.1682, 0.1744, 0.2596, 0.1023, 0.2189, 0.0690, 0.1469, 0.1010, 0.1821, 0.2639, 0.0815],
        "clients": [220, 250, 280],
        "request_size": [1795.62, 1768.44, 1892.33, 1548.11, 1203.78, 1444.59, 1821.29, 1382.67, 1347.73, 1862.59, 1304.72, 1401.99, 2034.13, 1918.86, 1976.56, 1234.45, 1596.24, 1663.41, 1739.98, 1912.12, 1265.37, 1956.79, 1360.58, 1661.87, 1229.21, 1483.47, 1945.26, 1731.16, 1746.15, 1295.78, 1815.32, 1993.24, 2001.34, 1154.12, 1938.84, 1168.07, 1634.07, 1820.42, 1741.61, 2071.97, 1624.98, 1531.03],
        "table_amount": 20,
        "cycles": 100,
        "requests": 500,
        "subscriptions": [700, 1000, 1300]
    },
}

# %% [markdown]
# ##### Defining DataFrame Structure

# %%
request_data : Dict[str, list] = {
    "request_id" : [],
    "request_client": [],
    "request_size": [],
    "request_delay": [],
    "request_diserialization": [],
    "request_serialization": [],
    "request_status": []
}


response_data : Dict[str, list] = {
    "response_id" : [],
    "response_client": [],
    "response_size": [],
    "response_delay": [],
    "response_diserialization": [],
    "response_serialization": [],
    "response_status": []
}

server_data : Dict[str, list] = {
    "processed_request_id": [],
    "processed_response_id": [],
    "processed_db_query_id": []
}

client_data : Dict[str, list] = {
    "issued_request_id": [],
    "processed_request_id": [],
    "is_request_delayed": []
}

cycle_data : Dict[str, list] = {
    "cycle": [],
    "client": [],
    "data_delay": [],
    "data_molding": []

}

# %% [markdown]
# ##### Defining Data Transfer Objects

# %%
# Class that collects inpormation per request and response pair
# format of list -> [id, client, size, delay, deserialization, serialiation]
class DataPackage:
    def __init__(self, issuer: str, recepient: str) -> None:
        self.issuer = issuer
        self.status = "process"
        self.recepient = recepient
        self.request : list = ["", "", 0, 0, 0, 0, "process"]
        self.response : list = ["", "", 0, 0, 0, 0, "process"]

    def __str__(self) -> str:
        return "Issuer:" + self.issuer +  " | Recepient: " + self.recepient + " | " + " Request: " + str(self.request) + " Response: " + str(self.response)

# %% [markdown]
# ##### Defining Utility Functions

# %%
def saveReqResData(request : DataPackage) -> DataPackage:
    request_id_list = request_data['request_id']
    request_id_list.append(request.request[0])

    request_client_list = request_data['request_client']
    request_client_list.append(request.request[1])

    request_size_list = request_data['request_size']
    request_size_list.append(request.request[2])

    request_delay_list = request_data['request_delay']
    request_delay_list.append(request.request[3])

    request_diserialization_list = request_data['request_diserialization']
    request_diserialization_list.append(request.request[4])

    request_serialization_list = request_data['request_serialization']
    request_serialization_list.append(request.request[5])

    request_serialization_list = request_data['request_status']
    request_serialization_list.append(request.request[6])


    response_id_list = response_data['response_id']
    response_id_list.append(request.response[0])

    response_client_list = response_data['response_client']
    response_client_list.append(request.response[1])

    response_size_list = response_data['response_size']
    response_size_list.append(request.response[2])

    response_delay_list = response_data['response_delay']
    response_delay_list.append(request.response[3])

    response_diserialization = response_data['response_diserialization']
    response_diserialization.append(request.response[4])

    response_serialization_list = response_data['response_serialization']
    response_serialization_list.append(request.response[5])

    response_serialization_list = response_data['response_status']
    response_serialization_list.append(request.response[6])

    return request


def saveCycleData(cycle_name: str, data: DataPackage) -> DataPackage:
    cycle_id = cycle_data["cycle"]
    cycle_id.append(cycle_name)

    cycle_data_client = cycle_data["client"]
    cycle_data_client.append(data.issuer)

    cycle_delay = cycle_data["data_delay"]
    cycle_delay.append(data.request[3] + data.request[4] + data.request[5] + data.response[3] + data.response[4] + data.response[5])

    cycle_molding = cycle_data['data_molding']
    cycle_molding.append(data.request[4] + data.request[5] + data.response[4] + data.response[5])

# %% [markdown]
# ### Set-up Simulation

# %% [markdown]
# ##### Settings

# %%
simulation_scale: str = input("Enter how big you want the scale of the simulation to be { small, medium, large }: ")


chosen_scale = settings[simulation_scale]

# %% [markdown]
# ##### Settin-up Data Structure

# %%
class FederatedNodeDatabase:
    t_rows = [10, 100, 1_000, 10_000]
    t_cols = [5, 7, 10]
    t_shards = [2,4,6]

    def __init__(self, name: str) -> None:
        self.name = name
        self.shards : Dict[str, List[Dict[str, List[list]]]] = {}
        for i in range(choice(self.t_shards)):
            self.create_shard("Shard " + str(i))

    def create_shard(self, shard_name: str) -> (str, List[Dict[str, List[list]]]):
        self.shards[shard_name] = []

    def remove_shard(self, shard_name) -> None:
        self.shards.pop(shard_name)

    def add_table(self, shard_name: str, table_name : str) -> Dict[str, List[list]]:
        shard = self.shards.get(shard_name)
        table = {
            table_name: [[0 for i in range(choice(self.t_cols))] for j in range(choice(self.t_rows))]
        }
        shard.append(table)
        return table

    def remove_table(self, shard_name : str, table_name : str) -> None:
        shard = self.shards.get(shard_name)

        for table in shard:
            if table_name in table.keys():
                table.pop(table_name)

# %%
class FederatedServer:
    def __init__(self, name: str) -> None:
        self.name = "Server " + name
        self.databse = FederatedNodeDatabase("DB " + name)
        self.node = None

    def issue_response(self, data: DataPackage) -> DataPackage:
        return self.node.capture_response(data= data)

    def generate_response(self, data: DataPackage) -> DataPackage:
        start_time = time()
        sleep(uniform(0.004, 0.10))
        end_time = time()
        completed_time = end_time - start_time
        data.response[5] = uniform(0.014, 0.30)

        return self.issue_response(data)

    def accept_request(self, data: DataPackage) -> DataPackage:
        start_time = time()
        sleep(uniform(0.004, 0.10))
        end_time = time()
        completed_time = end_time - start_time

        data.request[4] = completed_time
        return self.query_db(data= data)

    def query_db(self, data: DataPackage) -> DataPackage:
        start_time = time()
        sleep(uniform(0.004, 0.010))
        end_time = time()
        completed_time = end_time - start_time

        data.response[3] += uniform(0.01, 0.34)

        return self.generate_response(data= data)

# %%
class FederatedNode:

    def __init__(self,name: str) -> None:
        self.name = "Node " + name
        self.server = None
        self.subscribers : Dict[str, FederatedNode] = {}


    def attatch_server(self, server: FederatedServer) -> None:
        if(self.server == None):
            self.server = server
            server.node = self
        else:
            return

    def subscribe(self, node: FederatedNode) -> None:
        if node.name not in self.subscribers.keys():
            self.subscribers[node.name] = node
        else:
            return

    def issue_request(self, node_name : str) -> DataPackage:
        start_time = time()
        sleep(uniform(0.04, 0.14))
        end_time = time()
        completed_time = end_time - start_time

        data = DataPackage(issuer= self.name, recepient= node_name)
        data.request[0] = uuid4()
        data.request[1] = self.name
        data.request[2] = choice(chosen_scale['request_size'])
        data.request[5] = uniform(0.04, 0.34)
        data.request[6] = "process"

        data.response[1] = node_name
        data.response[0] = uuid4()

        return self.accept_request(data= data)

    def capture_response(self, data: DataPackage) -> DataPackage:
        start_time = time()
        sleep(uniform(0.004, 0.10))
        end_time = time()
        completed_time = end_time - start_time

        data.response[4] = completed_time

        return saveReqResData(data)

    def generate_response(self, data: DataPackage) -> DataPackage:
        start_time = time()
        sleep(uniform(0.004, 0.10))
        end_time = time()
        completed_time = end_time - start_time

        data.response[5] = completed_time
        data.response[3] = uniform(0.04, 0.35)

        return self.issue_response(data= data)

    def accept_request(self, data: DataPackage) -> DataPackage:

        if( data.recepient == self.name):
            data.request[3] += uniform(0.04, 0.34)
            return self.server.accept_request(data= data)

        if(data.recepient in self.subscribers.keys()):
            node = self.subscribers[data.recepient]

            data.request[3] += uniform(0.04, 0.34)
            return self.forward_request(node= node, data= data)

        else:
            start_time = time()
            sleep(uniform(0.004, 0.10))
            end_time = time()
            completed_time = end_time - start_time

            accept = choice(["process", "denied"])
            data.request[3] = uniform(0.04, 0.35)
            data.request[4] = choice(chosen_scale['delay'])
            data.request[6] = accept
            data.status = accept

            data.response[0] = data.request[0]
            data.response[1] = data.recepient
            data.response[2] = choice(chosen_scale['request_size'])
            data.response[3] = uniform(0.04, 0.32)
            data.response[4] = 0
            data.response[5] = uniform(0.06, 0.45)
            data.response[6] = accept

            return self.capture_response(data=data)


    def forward_request(self, node: FederatedNode, data: DataPackage) -> DataPackage:
        start_time = time()
        sleep(uniform(0.04, 0.23))
        end_time = time()
        completed_time = end_time - start_time

        data.request[3] = uniform(0.04, 0.35)

        return node.accept_request(data= data)

    def __str__(self) -> str:
        return "Node: " + self.name + " | " + "Subscribers: " + str(list(self.subscribers.values()))

# %% [markdown]
# ##### Set-Up Node Subscriptions

# %%
nodes : Dict[str, FederatedNode] = {}

print("|---------------------------- Generating  Nodes -----------------------------|")
for node_index in tqdm(range(choice(chosen_scale['clients'])),  desc= "Generating Nodes", position=0):
    sleep(0.03)
    server = FederatedServer(name=  str(node_index))
    node = FederatedNode(name= str(node_index))
    node.attatch_server(server= server)
    nodes[node.name] = node
print()
print("|---------------------------- Subscribing Nodes -----------------------------|")
for node_subscription_index in  tqdm(range(choice(chosen_scale['subscriptions'])),  desc= "Subscribing to Nodes"):
    random_node_to_subscribe = choice(list(nodes.values()))
    random_node_subscribing = choice(list(nodes.values()))
    sleep(0.012)
    while(random_node_subscribing in list(random_node_to_subscribe.subscribers.values())):
        random_node_subscribing = choice(list(nodes.values()))

    random_node_to_subscribe.subscribe(random_node_subscribing)

sleep(0.3)
print()
print("|-------------------------- Completed Node Setup ----------------------------|")

PrettyPrinter(width=10).pprint(nodes)
# Out:
# |---------------------------- Generating  Nodes -----------------------------|
# Generating Nodes:   3%|▎         | 4/130 [00:00<00:03, 32.26it/s]
# Generating Nodes: 100%|██████████| 130/130 [00:04<00:00, 32.22it/s]
# |---------------------------- Subscribing Nodes -----------------------------|
# Subscribing to Nodes: 100%|██████████| 700/700 [00:08<00:00, 78.62it/s]
# |-------------------------- Completed Node Setup ----------------------------|
# {'Node 0': <__main__.FederatedNode object at 0x0000023ECDFDD070>,
#  'Node 1': <__main__.FederatedNode object at 0x0000023ECDFDD6D0>,
#  'Node 10': <__main__.FederatedNode object at 0x0000023ECDFDE8D0>,
#  'Node 100': <__main__.FederatedNode object at 0x0000023ECE01C6B0>,
#  'Node 101': <__main__.FederatedNode object at 0x0000023ECE01C950>,
#  'Node 102': <__main__.FederatedNode object at 0x0000023ECE01CB30>,
#  'Node 103': <__main__.FederatedNode object at 0x0000023ECE01CD70>,
#  'Node 104': <__main__.FederatedNode object at 0x0000023ECE01D040>,
#  'Node 105': <__main__.FederatedNode object at 0x0000023ECE01D190>,
#  'Node 106': <__main__.FederatedNode object at 0x0000023ECE01D3D0>,
#  'Node 107': <__main__.FederatedNode object at 0x0000023ECE01D5B0>,
#  'Node 108': <__main__.FederatedNode object at 0x0000023ECE01D850>,
#  'Node 109': <__main__.FederatedNode object at 0x0000023ECE01DA30>,
#  'Node 11': <__main__.FederatedNode object at 0x0000023ECDFDC7D0>,
#  'Node 110': <__main__.FederatedNode object at 0x0000023ECE01DC10>,
#  'Node 111': <__main__.FederatedNode object at 0x0000023ECE01DD90>,
#  'Node 112': <__main__.FederatedNode object at 0x0000023ECE01E030>,
#  'Node 113': <__main__.FederatedNode object at 0x0000023ECE01E210>,
#  'Node 114': <__main__.FederatedNode object at 0x0000023ECE01E3F0>,
#  'Node 115': <__main__.FederatedNode object at 0x0000023ECE01E5D0>,
#  'Node 116': <__main__.FederatedNode object at 0x0000023ECE01E840>,
#  'Node 117': <__main__.FederatedNode object at 0x0000023ECE01EA20>,
#  'Node 118': <__main__.FederatedNode object at 0x0000023ECE01EBA0>,
#  'Node 119': <__main__.FederatedNode object at 0x0000023ECE01EDE0>,
#  'Node 12': <__main__.FederatedNode object at 0x0000023ECDFDFF20>,
#  'Node 120': <__main__.FederatedNode object at 0x0000023ECE01EFC0>,
#  'Node 121': <__main__.FederatedNode object at 0x0000023ECE01F230>,
#  'Node 122': <__main__.FederatedNode object at 0x0000023ECE01F410>,
#  'Node 123': <__main__.FederatedNode object at 0x0000023ECE01F650>,
#  'Node 124': <__main__.FederatedNode object at 0x0000023ECE01F800>,
#  'Node 125': <__main__.FederatedNode object at 0x0000023ECE01FA70>,
#  'Node 126': <__main__.FederatedNode object at 0x0000023ECE01FC50>,
#  'Node 127': <__main__.FederatedNode object at 0x0000023ECE01FDD0>,
#  'Node 128': <__main__.FederatedNode object at 0x0000023ECE01FF80>,
#  'Node 129': <__main__.FederatedNode object at 0x0000023ECE00C140>,
#  'Node 13': <__main__.FederatedNode object at 0x0000023ECDFDFF80>,
#  'Node 14': <__main__.FederatedNode object at 0x0000023ECDFDF3B0>,
#  'Node 15': <__main__.FederatedNode object at 0x0000023ECB9BADE0>,
#  'Node 16': <__main__.FederatedNode object at 0x0000023ECDFFF1D0>,
#  'Node 17': <__main__.FederatedNode object at 0x0000023ECDFFFD70>,
#  'Node 18': <__main__.FederatedNode object at 0x0000023ECDFFFA70>,
#  'Node 19': <__main__.FederatedNode object at 0x0000023ECDFFDB20>,
#  'Node 2': <__main__.FederatedNode object at 0x0000023ECDFDD580>,
#  'Node 20': <__main__.FederatedNode object at 0x0000023ECDFFCE60>,
#  'Node 21': <__main__.FederatedNode object at 0x0000023ECDFFE600>,
#  'Node 22': <__main__.FederatedNode object at 0x0000023ECDFFF260>,
#  'Node 23': <__main__.FederatedNode object at 0x0000023ECDFFDB80>,
#  'Node 24': <__main__.FederatedNode object at 0x0000023ECDFFF4D0>,
#  'Node 25': <__main__.FederatedNode object at 0x0000023ECDFFEF60>,
#  'Node 26': <__main__.FederatedNode object at 0x0000023ECDFFF560>,
#  'Node 27': <__main__.FederatedNode object at 0x0000023ECDFFF710>,
#  'Node 28': <__main__.FederatedNode object at 0x0000023ECDFFFA10>,
#  'Node 29': <__main__.FederatedNode object at 0x0000023ECDFFC500>,
#  'Node 3': <__main__.FederatedNode object at 0x0000023ECDFDDA00>,
#  'Node 30': <__main__.FederatedNode object at 0x0000023ECDFFDD30>,
#  'Node 31': <__main__.FederatedNode object at 0x0000023ECDFFD520>,
#  'Node 32': <__main__.FederatedNode object at 0x0000023ECDFFC290>,
#  'Node 33': <__main__.FederatedNode object at 0x0000023ECDFFC110>,
#  'Node 34': <__main__.FederatedNode object at 0x0000023ECDFFC8F0>,
#  'Node 35': <__main__.FederatedNode object at 0x0000023ECDFFC230>,
#  'Node 36': <__main__.FederatedNode object at 0x0000023ECDFFD160>,
#  'Node 37': <__main__.FederatedNode object at 0x0000023ECDFFC5C0>,
#  'Node 38': <__main__.FederatedNode object at 0x0000023ECDFB1C70>,
#  'Node 39': <__main__.FederatedNode object at 0x0000023ECDFB21B0>,
#  'Node 4': <__main__.FederatedNode object at 0x0000023ECDFDE990>,
#  'Node 40': <__main__.FederatedNode object at 0x0000023ECDFB13A0>,
#  'Node 41': <__main__.FederatedNode object at 0x0000023ECDFB0050>,
#  'Node 42': <__main__.FederatedNode object at 0x0000023ECDFB1D30>,
#  'Node 43': <__main__.FederatedNode object at 0x0000023ECDFB25A0>,
#  'Node 44': <__main__.FederatedNode object at 0x0000023ECDFB2210>,
#  'Node 45': <__main__.FederatedNode object at 0x0000023ECDFB2120>,
#  'Node 46': <__main__.FederatedNode object at 0x0000023ECDFB05F0>,
#  'Node 47': <__main__.FederatedNode object at 0x0000023ECDFB2480>,
#  'Node 48': <__main__.FederatedNode object at 0x0000023ECDFB2F90>,
#  'Node 49': <__main__.FederatedNode object at 0x0000023ECDFB3380>,
#  'Node 5': <__main__.FederatedNode object at 0x0000023ECDFDDD30>,
#  'Node 50': <__main__.FederatedNode object at 0x0000023ECDFB0650>,
#  'Node 51': <__main__.FederatedNode object at 0x0000023ECDFB36B0>,
#  'Node 52': <__main__.FederatedNode object at 0x0000023ECDFB3260>,
#  'Node 53': <__main__.FederatedNode object at 0x0000023ECDFB36E0>,
#  'Node 54': <__main__.FederatedNode object at 0x0000023ECDFB2F00>,
#  'Node 55': <__main__.FederatedNode object at 0x0000023ECDFB1940>,
#  'Node 56': <__main__.FederatedNode object at 0x0000023ECDFB1880>,
#  'Node 57': <__main__.FederatedNode object at 0x0000023ECDFB1730>,
#  'Node 58': <__main__.FederatedNode object at 0x0000023ECDFB12B0>,
#  'Node 59': <__main__.FederatedNode object at 0x0000023ECDFB0320>,
#  'Node 6': <__main__.FederatedNode object at 0x0000023ECDFDEAE0>,
#  'Node 60': <__main__.FederatedNode object at 0x0000023ECDFB3740>,
#  'Node 61': <__main__.FederatedNode object at 0x0000023ECDFB0FE0>,
#  'Node 62': <__main__.FederatedNode object at 0x0000023ECDFB0E60>,
#  'Node 63': <__main__.FederatedNode object at 0x0000023ECDF90500>,
#  'Node 64': <__main__.FederatedNode object at 0x0000023ECDF91B50>,
#  'Node 65': <__main__.FederatedNode object at 0x0000023ECDF93EC0>,
#  'Node 66': <__main__.FederatedNode object at 0x0000023ECDF917C0>,
#  'Node 67': <__main__.FederatedNode object at 0x0000023ECDF91160>,
#  'Node 68': <__main__.FederatedNode object at 0x0000023ECDF91010>,
#  'Node 69': <__main__.FederatedNode object at 0x0000023ECDF92990>,
#  'Node 7': <__main__.FederatedNode object at 0x0000023ECDFDE7E0>,
#  'Node 70': <__main__.FederatedNode object at 0x0000023ECDF91CD0>,
#  'Node 71': <__main__.FederatedNode object at 0x0000023ECDF93BF0>,
#  'Node 72': <__main__.FederatedNode object at 0x0000023ECDF938F0>,
#  'Node 73': <__main__.FederatedNode object at 0x0000023ECDF902F0>,
#  'Node 74': <__main__.FederatedNode object at 0x0000023ECDF933E0>,
#  'Node 75': <__main__.FederatedNode object at 0x0000023ECDF90710>,
#  'Node 76': <__main__.FederatedNode object at 0x0000023ECDF92240>,
#  'Node 77': <__main__.FederatedNode object at 0x0000023ECDF93080>,
#  'Node 78': <__main__.FederatedNode object at 0x0000023ECB9D89E0>,
#  'Node 79': <__main__.FederatedNode object at 0x0000023ECB9D9850>,
#  'Node 8': <__main__.FederatedNode object at 0x0000023ECDFDE4B0>,
#  'Node 80': <__main__.FederatedNode object at 0x0000023ECC6000B0>,
#  'Node 81': <__main__.FederatedNode object at 0x0000023ECC602630>,
#  'Node 82': <__main__.FederatedNode object at 0x0000023ECC603FE0>,
#  'Node 83': <__main__.FederatedNode object at 0x0000023ECC52AD80>,
#  'Node 84': <__main__.FederatedNode object at 0x0000023ECB9F9250>,
#  'Node 85': <__main__.FederatedNode object at 0x0000023ECC5A1E20>,
#  'Node 86': <__main__.FederatedNode object at 0x0000023ECC5C5130>,
#  'Node 87': <__main__.FederatedNode object at 0x0000023ECC5C5CD0>,
#  'Node 88': <__main__.FederatedNode object at 0x0000023ECC5C5D30>,
#  'Node 89': <__main__.FederatedNode object at 0x0000023ECC5C6150>,
#  'Node 9': <__main__.FederatedNode object at 0x0000023ECDFDF530>,
#  'Node 90': <__main__.FederatedNode object at 0x0000023ECC5B6BA0>,
#  'Node 91': <__main__.FederatedNode object at 0x0000023ECC5B7EF0>,
#  'Node 92': <__main__.FederatedNode object at 0x0000023ECC5B6960>,
#  'Node 93': <__main__.FederatedNode object at 0x0000023ECC6183B0>,
#  'Node 94': <__main__.FederatedNode object at 0x0000023ECC618140>,
#  'Node 95': <__main__.FederatedNode object at 0x0000023ECC61AF60>,
#  'Node 96': <__main__.FederatedNode object at 0x0000023ECC618350>,
#  'Node 97': <__main__.FederatedNode object at 0x0000023ECE01C170>,
#  'Node 98': <__main__.FederatedNode object at 0x0000023ECE01C320>,
#  'Node 99': <__main__.FederatedNode object at 0x0000023ECE01C530>}

# %% [markdown]
# ##### Running the simulation

# %%
sys.setrecursionlimit(10_000)

for cycle in tqdm(range(chosen_scale['cycles']), desc= "Running Simulation: " + str(chosen_scale["cycles"] ) + " Cycles in total", position=0):
        for request in tqdm(range(chosen_scale["requests"]), desc= "Current Cycle: " + str(cycle + 1), position=1):
                node = choice(list(nodes.values()))
                saveCycleData("Cycle: " + str(cycle + 1), node.issue_request(choice(list(nodes.keys()))))
# Out:
# Current Cycle: 1: 100%|██████████| 100/100 [00:21<00:00,  4.76it/s]0<?, ?it/s]
# Current Cycle: 2: 100%|██████████| 100/100 [00:21<00:00,  4.68it/s]1<10:09, 21.01s/it]
# Current Cycle: 3: 100%|██████████| 100/100 [00:21<00:00,  4.72it/s]2<09:54, 21.23s/it]
# Current Cycle: 4: 100%|██████████| 100/100 [00:19<00:00,  5.00it/s]3<09:32, 21.21s/it]
# Current Cycle: 5: 100%|██████████| 100/100 [00:21<00:00,  4.71it/s]3<08:59, 20.73s/it]
# Current Cycle: 6: 100%|██████████| 100/100 [00:20<00:00,  4.94it/s]4<08:42, 20.91s/it]
# Current Cycle: 7: 100%|██████████| 100/100 [00:20<00:00,  4.80it/s]5<08:16, 20.69s/it]
# Current Cycle: 8: 100%|██████████| 100/100 [00:19<00:00,  5.10it/s]5<07:57, 20.74s/it]
# Current Cycle: 9: 100%|██████████| 100/100 [00:21<00:00,  4.70it/s]5<07:28, 20.38s/it]
# Current Cycle: 10: 100%|██████████| 100/100 [00:20<00:00,  4.89it/s]<07:14, 20.67s/it]
# Current Cycle: 11: 100%|██████████| 100/100 [00:19<00:00,  5.07it/s]7<06:52, 20.61s/it]
# Current Cycle: 12: 100%|██████████| 100/100 [00:20<00:00,  4.90it/s]7<06:26, 20.34s/it]
# Current Cycle: 13: 100%|██████████| 100/100 [00:20<00:00,  4.93it/s]7<06:06, 20.36s/it]
# Current Cycle: 14: 100%|██████████| 100/100 [00:21<00:00,  4.61it/s]7<05:45, 20.34s/it]
# Current Cycle: 15: 100%|██████████| 100/100 [00:20<00:00,  4.98it/s]9<05:31, 20.74s/it]
# Current Cycle: 16: 100%|██████████| 100/100 [00:21<00:00,  4.71it/s]9<05:08, 20.55s/it]
# Current Cycle: 17: 100%|██████████| 100/100 [00:21<00:00,  4.66it/s]0<04:50, 20.76s/it]
# Current Cycle: 18: 100%|██████████| 100/100 [00:19<00:00,  5.00it/s]2<04:32, 20.98s/it]
# Current Cycle: 19: 100%|██████████| 100/100 [00:20<00:00,  4.84it/s]2<04:08, 20.68s/it]
# Current Cycle: 20: 100%|██████████| 100/100 [00:20<00:00,  4.90it/s]2<03:47, 20.68s/it]
# Current Cycle: 21: 100%|██████████| 100/100 [00:21<00:00,  4.59it/s]3<03:26, 20.61s/it]
# Current Cycle: 22: 100%|██████████| 100/100 [00:20<00:00,  4.88it/s]5<03:08, 20.95s/it]
# Current Cycle: 23: 100%|██████████| 100/100 [00:20<00:00,  4.94it/s]5<02:46, 20.82s/it]
# Current Cycle: 24: 100%|██████████| 100/100 [00:21<00:00,  4.71it/s]5<02:24, 20.64s/it]
# Current Cycle: 25: 100%|██████████| 100/100 [00:19<00:00,  5.00it/s]7<02:04, 20.83s/it]
# Current Cycle: 26: 100%|██████████| 100/100 [00:20<00:00,  4.98it/s]7<01:42, 20.58s/it]
# Current Cycle: 27: 100%|██████████| 100/100 [00:21<00:00,  4.61it/s]7<01:21, 20.43s/it]
# Current Cycle: 28: 100%|██████████| 100/100 [00:21<00:00,  4.71it/s]8<01:02, 20.80s/it]
# Current Cycle: 29: 100%|██████████| 100/100 [00:21<00:00,  4.65it/s]0<00:41, 20.93s/it]
# Current Cycle: 30: 100%|██████████| 100/100 [00:21<00:00,  4.75it/s]1<00:21, 21.10s/it]
# Running Simulation: 30 Cycles in total: 100%|██████████| 30/30 [10:22<00:00, 20.75s/it]

# %% [markdown]
# ### Simulation Results

# %% [markdown]
# ##### Requests Delay and Information propagation

# %%
request_dataset = pd.DataFrame(request_data)
response_dataset = pd.DataFrame(response_data)

request_delays = request_dataset[["request_delay", "request_diserialization", "request_serialization"]]
response_delays = response_dataset[["response_delay", "response_diserialization", "response_serialization"]]

# %%
request_dataset

request_dataset.loc[request_dataset['request_status'] == "process"]
# Out:
#                                 request_id request_client  request_size  \
# 2     6a717d69-8fee-45fe-b964-85d2e7304e28       Node 101       1216.62
# 3     8fef4510-2223-4ee2-a945-119b5643926c       Node 124       1251.37
# 4     13056d0c-6a9d-4ba9-9fc8-7d6c32965340        Node 65       1142.19
# 7     13c7276a-f09b-4f07-afef-f6b0c67a52a9        Node 95       1129.98
# 8     f0aa0c4a-1098-452e-b8a0-c074ce44df4d        Node 94        618.25
# ...                                    ...            ...           ...
# 2991  e949b643-975e-44b9-95ec-e43b424c9361        Node 58       1142.19
# 2993  11098da5-c910-4c0d-aa9d-dd33d96f13c8        Node 95       1230.16
# 2995  62ef6af5-7da4-4daf-a8b5-6f9fb7696709       Node 127       1066.06
# 2997  39a9a0db-46e5-4b13-84a9-675bbc880761        Node 36        618.25
# 2999  26050e55-1761-4d74-aea3-bda353dbdf27        Node 47       1270.73
#
#       request_delay  request_diserialization  request_serialization  \
# 2          0.517760                 0.043001               0.069267
# 3          0.344525                 0.076900               0.253209
# 4          0.270340                 0.049100               0.275598
# 7          0.273725                 0.237900               0.073437
# 8          0.244123                 0.178400               0.186257
# ...             ...                      ...                    ...
# 2991       0.264023                 0.214800               0.140612
# 2993       0.070144                 0.265800               0.227432
# 2995       0.047562                 0.108000               0.194855
# 2997       0.311136                 0.062300               0.232191
# 2999       0.178564                 0.274200               0.183974
#
#      request_status
# 2           process
# 3           process
# 4           process
# 7           process
# 8           process
# ...             ...
# 2991        process
# 2993        process
# 2995        process
# 2997        process
# 2999        process
#
# [1602 rows x 7 columns]

# %%
request_delays
# Out:
#       request_delay  request_diserialization  request_serialization
# 0          0.318789                 0.186600               0.105516
# 1          0.251438                 0.208200               0.285036
# 2          0.517760                 0.043001               0.069267
# 3          0.344525                 0.076900               0.253209
# 4          0.270340                 0.049100               0.275598
# ...             ...                      ...                    ...
# 2995       0.047562                 0.108000               0.194855
# 2996       0.300943                 0.196800               0.142047
# 2997       0.311136                 0.062300               0.232191
# 2998       0.136966                 0.174400               0.080874
# 2999       0.178564                 0.274200               0.183974
#
# [3000 rows x 3 columns]

# %%
request_delays.plot.hist(alpha=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ##### Cycle Statistics

# %%
cycle_dataset = pd.DataFrame(cycle_data)
bar_plot_selection = cycle_dataset[['cycle', 'data_delay']]
bar_plot_data = {}


temp : Dict[str, List[float]] = {}

cycle_col_one_list = bar_plot_selection['cycle'].tolist()
cycle_col_two_list  = bar_plot_selection['data_delay'].tolist()

for cycle in tqdm(range(len(cycle_col_one_list))):
    sleep(0.001)
    if cycle_col_one_list[cycle] in temp.keys():
        list_of_floats = temp[cycle_col_one_list[cycle]]
        list_of_floats.append(cycle_col_two_list[cycle])
        temp.update({
            cycle_col_one_list[cycle] : list_of_floats
        })
    else:
        list_of_floats = []
        list_of_floats.append(cycle_col_two_list[cycle])
        temp.update({
            cycle_col_one_list[cycle] : list_of_floats
        })

for cycle, list_of_delays in temp.items():
    avg = round(sum(list_of_delays) / len(list_of_delays),8)
    bar_plot_data.update({
        cycle : avg
    })


plt.figure(figsize=(20,5))
plt.title("Average Cycle Delay", size = 20)
plt.bar(bar_plot_data.keys(), bar_plot_data.values(), width=0.4, color= "#0d9488")
# Out:
# 100%|██████████| 3000/3000 [00:05<00:00, 566.21it/s]
# <BarContainer object of 30 artists>

# %%
plt.figure(figsize=(20,10))
plt.title("Request propagation", size = 20)
plt.xlabel("Request Serialization")
plt.ylabel("Request De-Serialization")
plt.scatter(request_delays['request_diserialization'], request_delays["request_serialization"] , c="#0d9488", s= 50)
plt.show()
