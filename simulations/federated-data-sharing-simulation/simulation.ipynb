# %% [markdown]
# # FEDeRATED Data Sharing

# %% [markdown]
# ### Dependency Syncronization

# %% [markdown]
# ##### Downloading Libraries

# %%
import sys

# Installing numpy
# !{sys.executable} -m pip install numpy

# Installing pandas
# !{sys.executable} -m pip install pandas

# Installing matplotlib
# !{sys.executable} -m pip install matplotlib

#Installing tqdm
# !{sys.executable} -m pip install tqdm
# Out:
# Requirement already satisfied: numpy in c:\python312\lib\site-packages (1.26.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\python312\lib\site-packages (2.1.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\python312\lib\site-packages (from pandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pc\appdata\roaming\python\python312\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python312\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\python312\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\pc\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\python312\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python312\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python312\lib\site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\python312\lib\site-packages (from matplotlib) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\pc\appdata\roaming\python\python312\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\python312\lib\site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python312\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pc\appdata\roaming\python\python312\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\pc\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tqdm in c:\python312\lib\site-packages (4.66.1)
# Requirement already satisfied: colorama in c:\users\pc\appdata\roaming\python\python312\site-packages (from tqdm) (0.4.6)
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ##### Importing Packages

# %%
# Import Native Libraries
from __future__             import annotations
# Import Statistic Libraries
import numpy                as np
import pandas               as pd
import matplotlib.pyplot    as plt

# Import Utility Libraries
from typing                 import List, Dict
from random                 import choice, random, uniform
from time                   import sleep, time
from tqdm                   import tqdm
from uuid                   import uuid4
from pprint                 import PrettyPrinter

# %% [markdown]
# ### Simulation Definition

# %% [markdown]
# ##### Defining Settings

# %%
settings : Dict[str, Dict[str, list]] = {
    "test": {
        "delay": [0.0623, 0.2585, 0.2238, 0.1017, 0.1276, 0.1784, 0.2742, 0.0865, 0.2951, 0.1953, 0.1379, 0.2407, 0.2814, 0.0792, 0.2079, 0.0334, 0.2646, 0.1551, 0.1687, 0.1158, 0.2923, 0.0491, 0.0483, 0.1937, 0.1769, 0.0687, 0.2799, 0.0962, 0.0649, 0.1206, 0.2624, 0.2910, 0.2105, 0.0703, 0.1508, 0.1326, 0.0420, 0.1564, 0.0523, 0.2379, 0.2849, 0.0850, 0.1841, 0.2148, 0.1986, 0.1080, 0.1968, 0.2271, 0.1736, 0.2264, 0.2318, 0.2589, 0.0769, 0.1436, 0.2916, 0.2082, 0.1828, 0.0896, 0.2480, 0.1866, 0.2363, 0.1616, 0.1847, 0.0503, 0.0584, 0.1064, 0.2280, 0.1586, 0.1636, 0.2557, 0.1175, 0.2690, 0.2249, 0.2658, 0.0698, 0.2257, 0.1611, 0.0554, 0.1464, 0.1236, 0.0754, 0.2195, 0.1030, 0.0941, 0.1789, 0.0912, 0.1300, 0.1357, 0.0890, 0.1321, 0.0761, 0.1052, 0.2538, 0.0377, 0.0874, 0.1216, 0.0668, 0.2142, 0.0736, 0.1406, 0.1667, 0.1594, 0.1445, 0.2749, 0.2213, 0.1682, 0.1744, 0.2596, 0.1023, 0.2189, 0.0690, 0.1469, 0.1010, 0.1821, 0.2639, 0.0815],
        "clients": [30, 50, 70],
        "request_size": [908.37, 1362.41, 1378.55, 1216.62, 1397.12, 1080.28, 1347.66, 771.84, 1210.19, 1132.47, 1121.89, 727.93, 1252.64, 1270.73, 1229.83, 681.42, 1336.58, 1220.45, 618.25, 1066.06, 614.17, 1087.92, 1129.98, 1291.54, 1142.19, 795.73, 1137.28, 1144.31, 1420.39, 798.51, 1074.12, 1403.45, 1092.63, 1071.97, 1234.51, 1251.37, 1230.16, 731.79, 991.47, 1256.16, 749.84],
        "table_amount": 20,
        "cycles": 10,
        "requests": 10,
        "subscriptions": [100, 150, 200]
    },
    "small": {
        "delay": [0.0623, 0.2585, 0.2238, 0.1017, 0.1276, 0.1784, 0.2742, 0.0865, 0.2951, 0.1953, 0.1379, 0.2407, 0.2814, 0.0792, 0.2079, 0.0334, 0.2646, 0.1551, 0.1687, 0.1158, 0.2923, 0.0491, 0.0483, 0.1937, 0.1769, 0.0687, 0.2799, 0.0962, 0.0649, 0.1206, 0.2624, 0.2910, 0.2105, 0.0703, 0.1508, 0.1326, 0.0420, 0.1564, 0.0523, 0.2379, 0.2849, 0.0850, 0.1841, 0.2148, 0.1986, 0.1080, 0.1968, 0.2271, 0.1736, 0.2264, 0.2318, 0.2589, 0.0769, 0.1436, 0.2916, 0.2082, 0.1828, 0.0896, 0.2480, 0.1866, 0.2363, 0.1616, 0.1847, 0.0503, 0.0584, 0.1064, 0.2280, 0.1586, 0.1636, 0.2557, 0.1175, 0.2690, 0.2249, 0.2658, 0.0698, 0.2257, 0.1611, 0.0554, 0.1464, 0.1236, 0.0754, 0.2195, 0.1030, 0.0941, 0.1789, 0.0912, 0.1300, 0.1357, 0.0890, 0.1321, 0.0761, 0.1052, 0.2538, 0.0377, 0.0874, 0.1216, 0.0668, 0.2142, 0.0736, 0.1406, 0.1667, 0.1594, 0.1445, 0.2749, 0.2213, 0.1682, 0.1744, 0.2596, 0.1023, 0.2189, 0.0690, 0.1469, 0.1010, 0.1821, 0.2639, 0.0815],
        "clients": [70, 100, 130],
        "request_size": [908.37, 1362.41, 1378.55, 1216.62, 1397.12, 1080.28, 1347.66, 771.84, 1210.19, 1132.47, 1121.89, 727.93, 1252.64, 1270.73, 1229.83, 681.42, 1336.58, 1220.45, 618.25, 1066.06, 614.17, 1087.92, 1129.98, 1291.54, 1142.19, 795.73, 1137.28, 1144.31, 1420.39, 798.51, 1074.12, 1403.45, 1092.63, 1071.97, 1234.51, 1251.37, 1230.16, 731.79, 991.47, 1256.16, 749.84],
        "table_amount": 20,
        "cycles": 30,
        "requests": 100,
        "subscriptions": [210, 450, 700]
    },
    "medium": {
        "delay": [0.0623, 0.2585, 0.2238, 0.1017, 0.1276, 0.1784, 0.2742, 0.0865, 0.2951, 0.1953, 0.1379, 0.2407, 0.2814, 0.0792, 0.2079, 0.0334, 0.2646, 0.1551, 0.1687, 0.1158, 0.2923, 0.0491, 0.0483, 0.1937, 0.1769, 0.0687, 0.2799, 0.0962, 0.0649, 0.1206, 0.2624, 0.2910, 0.2105, 0.0703, 0.1508, 0.1326, 0.0420, 0.1564, 0.0523, 0.2379, 0.2849, 0.0850, 0.1841, 0.2148, 0.1986, 0.1080, 0.1968, 0.2271, 0.1736, 0.2264, 0.2318, 0.2589, 0.0769, 0.1436, 0.2916, 0.2082, 0.1828, 0.0896, 0.2480, 0.1866, 0.2363, 0.1616, 0.1847, 0.0503, 0.0584, 0.1064, 0.2280, 0.1586, 0.1636, 0.2557, 0.1175, 0.2690, 0.2249, 0.2658, 0.0698, 0.2257, 0.1611, 0.0554, 0.1464, 0.1236, 0.0754, 0.2195, 0.1030, 0.0941, 0.1789, 0.0912, 0.1300, 0.1357, 0.0890, 0.1321, 0.0761, 0.1052, 0.2538, 0.0377, 0.0874, 0.1216, 0.0668, 0.2142, 0.0736, 0.1406, 0.1667, 0.1594, 0.1445, 0.2749, 0.2213, 0.1682, 0.1744, 0.2596, 0.1023, 0.2189, 0.0690, 0.1469, 0.1010, 0.1821, 0.2639, 0.0815],
        "clients": [160, 190, 220],
        "request_size": [1372.54, 1512.23, 1261.89, 1639.67, 1155.12, 1212.45, 1689.34, 1445.76, 1399.88, 1089.23, 1577.43, 1755.69, 1345.98, 1234.76, 1650.32, 1123.56, 1498.45, 1750.12, 1023.89, 1289.76, 1756.23, 1199.45, 1323.67, 1545.21, 1687.99, 1290.34, 1376.65, 1467.34, 1611.78, 1712.56, 1211.99, 1122.34, 1423.78, 1544.23, 1665.45, 1734.56, 1089.12, 1512.67, 1311.45, 1789.56, 1066.23],
        "table_amount": 20,
        "cycles": 50,
        "requests": 300,
        "subscriptions": [400, 600, 800]

    },
    "large": {
        "delay": [0.0623, 0.2585, 0.2238, 0.1017, 0.1276, 0.1784, 0.2742, 0.0865, 0.2951, 0.1953, 0.1379, 0.2407, 0.2814, 0.0792, 0.2079, 0.0334, 0.2646, 0.1551, 0.1687, 0.1158, 0.2923, 0.0491, 0.0483, 0.1937, 0.1769, 0.0687, 0.2799, 0.0962, 0.0649, 0.1206, 0.2624, 0.2910, 0.2105, 0.0703, 0.1508, 0.1326, 0.0420, 0.1564, 0.0523, 0.2379, 0.2849, 0.0850, 0.1841, 0.2148, 0.1986, 0.1080, 0.1968, 0.2271, 0.1736, 0.2264, 0.2318, 0.2589, 0.0769, 0.1436, 0.2916, 0.2082, 0.1828, 0.0896, 0.2480, 0.1866, 0.2363, 0.1616, 0.1847, 0.0503, 0.0584, 0.1064, 0.2280, 0.1586, 0.1636, 0.2557, 0.1175, 0.2690, 0.2249, 0.2658, 0.0698, 0.2257, 0.1611, 0.0554, 0.1464, 0.1236, 0.0754, 0.2195, 0.1030, 0.0941, 0.1789, 0.0912, 0.1300, 0.1357, 0.0890, 0.1321, 0.0761, 0.1052, 0.2538, 0.0377, 0.0874, 0.1216, 0.0668, 0.2142, 0.0736, 0.1406, 0.1667, 0.1594, 0.1445, 0.2749, 0.2213, 0.1682, 0.1744, 0.2596, 0.1023, 0.2189, 0.0690, 0.1469, 0.1010, 0.1821, 0.2639, 0.0815],
        "clients": [220, 250, 280],
        "request_size": [1795.62, 1768.44, 1892.33, 1548.11, 1203.78, 1444.59, 1821.29, 1382.67, 1347.73, 1862.59, 1304.72, 1401.99, 2034.13, 1918.86, 1976.56, 1234.45, 1596.24, 1663.41, 1739.98, 1912.12, 1265.37, 1956.79, 1360.58, 1661.87, 1229.21, 1483.47, 1945.26, 1731.16, 1746.15, 1295.78, 1815.32, 1993.24, 2001.34, 1154.12, 1938.84, 1168.07, 1634.07, 1820.42, 1741.61, 2071.97, 1624.98, 1531.03],
        "table_amount": 20,
        "cycles": 100,
        "requests": 500,
        "subscriptions": [700, 1000, 1300]
    },
}

# %% [markdown]
# ##### Defining DataFrame Structure

# %%
request_data : Dict[str, list] = {
    "request_id" : [],
    "request_client": [],
    "request_size": [],
    "request_delay": [],
    "request_diserialization": [],
    "request_serialization": [],
    "request_status": []
}


response_data : Dict[str, list] = {
    "response_id" : [],
    "response_client": [],
    "response_size": [],
    "response_delay": [],
    "response_diserialization": [],
    "response_serialization": [],
    "response_status": []
}

server_data : Dict[str, list] = {
    "processed_request_id": [],
    "processed_response_id": [],
    "processed_db_query_id": []
}

client_data : Dict[str, list] = {
    "issued_request_id": [],
    "processed_request_id": [],
    "is_request_delayed": []
}

cycle_data : Dict[str, list] = {
    "cycle": [],
    "client": [],
    "data_delay": [],
    "data_molding": []

}

# %% [markdown]
# ##### Defining Data Transfer Objects

# %%
# Class that collects inpormation per request and response pair
# format of list -> [id, client, size, delay, deserialization, serialiation]
class DataPackage:
    def __init__(self, issuer: str, recepient: str) -> None:
        self.issuer = issuer
        self.status = "process"
        self.recepient = recepient
        self.request : list = ["", "", 0, 0, 0, 0, "process"]
        self.response : list = ["", "", 0, 0, 0, 0, "process"]

    def __str__(self) -> str:
        return "Issuer:" + self.issuer +  " | Recepient: " + self.recepient + " | " + " Request: " + str(self.request) + " Response: " + str(self.response)

# %% [markdown]
# ##### Defining Utility Functions

# %%
def saveReqResData(request : DataPackage) -> DataPackage:
    request_id_list = request_data['request_id']
    request_id_list.append(request.request[0])

    request_client_list = request_data['request_client']
    request_client_list.append(request.request[1])

    request_size_list = request_data['request_size']
    request_size_list.append(request.request[2])

    request_delay_list = request_data['request_delay']
    request_delay_list.append(request.request[3])

    request_diserialization_list = request_data['request_diserialization']
    request_diserialization_list.append(request.request[4])

    request_serialization_list = request_data['request_serialization']
    request_serialization_list.append(request.request[5])

    request_serialization_list = request_data['request_status']
    request_serialization_list.append(request.request[6])


    response_id_list = response_data['response_id']
    response_id_list.append(request.response[0])

    response_client_list = response_data['response_client']
    response_client_list.append(request.response[1])

    response_size_list = response_data['response_size']
    response_size_list.append(request.response[2])

    response_delay_list = response_data['response_delay']
    response_delay_list.append(request.response[3])

    response_diserialization = response_data['response_diserialization']
    response_diserialization.append(request.response[4])

    response_serialization_list = response_data['response_serialization']
    response_serialization_list.append(request.response[5])

    response_serialization_list = response_data['response_status']
    response_serialization_list.append(request.response[6])

    return request


def saveCycleData(cycle_name: str, data: DataPackage) -> DataPackage:
    cycle_id = cycle_data["cycle"]
    cycle_id.append(cycle_name)

    cycle_data_client = cycle_data["client"]
    cycle_data_client.append(data.issuer)

    cycle_delay = cycle_data["data_delay"]
    cycle_delay.append(data.request[3] + data.request[4] + data.request[5] + data.response[3] + data.response[4] + data.response[5])

    cycle_molding = cycle_data['data_molding']
    cycle_molding.append(data.request[4] + data.request[5] + data.response[4] + data.response[5])

# %% [markdown]
# ### Set-up Simulation

# %% [markdown]
# ##### Settings

# %%
simulation_scale: str = input("Enter how big you want the scale of the simulation to be { small, medium, large }: ")


chosen_scale = settings[simulation_scale]

# %% [markdown]
# ##### Settin-up Data Structure

# %%
class FederatedNodeDatabase:
    t_rows = [10, 100, 1_000, 10_000]
    t_cols = [5, 7, 10]
    t_shards = [2,4,6]

    def __init__(self, name: str) -> None:
        self.name = name
        self.shards : Dict[str, List[Dict[str, List[list]]]] = {}
        for i in range(choice(self.t_shards)):
            self.create_shard("Shard " + str(i))

    def create_shard(self, shard_name: str) -> (str, List[Dict[str, List[list]]]):
        self.shards[shard_name] = []

    def remove_shard(self, shard_name) -> None:
        self.shards.pop(shard_name)

    def add_table(self, shard_name: str, table_name : str) -> Dict[str, List[list]]:
        shard = self.shards.get(shard_name)
        table = {
            table_name: [[0 for i in range(choice(self.t_cols))] for j in range(choice(self.t_rows))]
        }
        shard.append(table)
        return table

    def remove_table(self, shard_name : str, table_name : str) -> None:
        shard = self.shards.get(shard_name)

        for table in shard:
            if table_name in table.keys():
                table.pop(table_name)

# %%
class FederatedServer:
    def __init__(self, name: str) -> None:
        self.name = "Server " + name
        self.databse = FederatedNodeDatabase("DB " + name)
        self.node = None

    def issue_response(self, data: DataPackage) -> DataPackage:
        return self.node.capture_response(data= data)

    def generate_response(self, data: DataPackage) -> DataPackage:
        start_time = time()
        sleep(uniform(0.004, 0.10))
        end_time = time()
        completed_time = end_time - start_time
        data.response[5] = uniform(0.014, 0.30)

        return self.issue_response(data)

    def accept_request(self, data: DataPackage) -> DataPackage:
        start_time = time()
        sleep(uniform(0.004, 0.10))
        end_time = time()
        completed_time = end_time - start_time

        data.request[4] = completed_time
        return self.query_db(data= data)

    def query_db(self, data: DataPackage) -> DataPackage:
        start_time = time()
        sleep(uniform(0.004, 0.010))
        end_time = time()
        completed_time = end_time - start_time

        data.response[3] += uniform(0.01, 0.34)

        return self.generate_response(data= data)

# %%
class FederatedNode:

    def __init__(self,name: str) -> None:
        self.name = "Node " + name
        self.server = None
        self.subscribers : Dict[str, FederatedNode] = {}


    def attatch_server(self, server: FederatedServer) -> None:
        if(self.server == None):
            self.server = server
            server.node = self
        else:
            return

    def subscribe(self, node: FederatedNode) -> None:
        if node.name not in self.subscribers.keys():
            self.subscribers[node.name] = node
        else:
            return

    def issue_request(self, node_name : str) -> DataPackage:
        start_time = time()
        sleep(uniform(0.04, 0.14))
        end_time = time()
        completed_time = end_time - start_time

        data = DataPackage(issuer= self.name, recepient= node_name)
        data.request[0] = uuid4()
        data.request[1] = self.name
        data.request[2] = choice(chosen_scale['request_size'])
        data.request[5] = uniform(0.04, 0.34)
        data.request[6] = "process"

        data.response[1] = node_name
        data.response[0] = uuid4()

        return self.accept_request(data= data)

    def capture_response(self, data: DataPackage) -> DataPackage:
        start_time = time()
        sleep(uniform(0.004, 0.10))
        end_time = time()
        completed_time = end_time - start_time

        data.response[4] = completed_time

        return saveReqResData(data)

    def generate_response(self, data: DataPackage) -> DataPackage:
        start_time = time()
        sleep(uniform(0.004, 0.10))
        end_time = time()
        completed_time = end_time - start_time

        data.response[5] = completed_time
        data.response[3] = uniform(0.04, 0.35)

        return self.issue_response(data= data)

    def accept_request(self, data: DataPackage) -> DataPackage:

        if( data.recepient == self.name):
            data.request[3] += uniform(0.04, 0.34)
            return self.server.accept_request(data= data)

        if(data.recepient in self.subscribers.keys()):
            node = self.subscribers[data.recepient]

            data.request[3] += uniform(0.04, 0.34)
            return self.forward_request(node= node, data= data)

        else:
            start_time = time()
            sleep(uniform(0.004, 0.10))
            end_time = time()
            completed_time = end_time - start_time

            accept = choice(["process", "denied"])
            data.request[3] = uniform(0.04, 0.35)
            data.request[4] = choice(chosen_scale['delay'])
            data.request[6] = accept
            data.status = accept

            data.response[0] = data.request[0]
            data.response[1] = data.recepient
            data.response[2] = choice(chosen_scale['request_size'])
            data.response[3] = uniform(0.04, 0.32)
            data.response[4] = 0
            data.response[5] = uniform(0.06, 0.45)
            data.response[6] = accept

            return self.capture_response(data=data)


    def forward_request(self, node: FederatedNode, data: DataPackage) -> DataPackage:
        start_time = time()
        sleep(uniform(0.04, 0.23))
        end_time = time()
        completed_time = end_time - start_time

        data.request[3] = uniform(0.04, 0.35)

        return node.accept_request(data= data)

    def __str__(self) -> str:
        return "Node: " + self.name + " | " + "Subscribers: " + str(list(self.subscribers.values()))

# %% [markdown]
# ##### Set-Up Node Subscriptions

# %%
nodes : Dict[str, FederatedNode] = {}

print("|---------------------------- Generating  Nodes -----------------------------|")
for node_index in tqdm(range(choice(chosen_scale['clients'])),  desc= "Generating Nodes", position=0):
    sleep(0.03)
    server = FederatedServer(name=  str(node_index))
    node = FederatedNode(name= str(node_index))
    node.attatch_server(server= server)
    nodes[node.name] = node
print()
print("|---------------------------- Subscribing Nodes -----------------------------|")
for node_subscription_index in  tqdm(range(choice(chosen_scale['subscriptions'])),  desc= "Subscribing to Nodes"):
    random_node_to_subscribe = choice(list(nodes.values()))
    random_node_subscribing = choice(list(nodes.values()))
    sleep(0.012)
    while(random_node_subscribing in list(random_node_to_subscribe.subscribers.values())):
        random_node_subscribing = choice(list(nodes.values()))

    random_node_to_subscribe.subscribe(random_node_subscribing)

sleep(0.3)
print()
print("|-------------------------- Completed Node Setup ----------------------------|")

PrettyPrinter(width=10).pprint(nodes)
# Out:
# |---------------------------- Generating  Nodes -----------------------------|
# Generating Nodes: 100%|██████████| 160/160 [00:05<00:00, 31.86it/s]
# |---------------------------- Subscribing Nodes -----------------------------|
# Subscribing to Nodes: 100%|██████████| 600/600 [00:07<00:00, 77.17it/s]
# |-------------------------- Completed Node Setup ----------------------------|
# {'Node 0': <__main__.FederatedNode object at 0x0000022E0BD77FB0>,
#  'Node 1': <__main__.FederatedNode object at 0x0000022E0E3516A0>,
#  'Node 10': <__main__.FederatedNode object at 0x0000022E0E3BC500>,
#  'Node 100': <__main__.FederatedNode object at 0x0000022E0E408590>,
#  'Node 101': <__main__.FederatedNode object at 0x0000022E0E4086B0>,
#  'Node 102': <__main__.FederatedNode object at 0x0000022E0E408830>,
#  'Node 103': <__main__.FederatedNode object at 0x0000022E0E408A70>,
#  'Node 104': <__main__.FederatedNode object at 0x0000022E0E408F20>,
#  'Node 105': <__main__.FederatedNode object at 0x0000022E0E408EF0>,
#  'Node 106': <__main__.FederatedNode object at 0x0000022E0E409220>,
#  'Node 107': <__main__.FederatedNode object at 0x0000022E0E4093D0>,
#  'Node 108': <__main__.FederatedNode object at 0x0000022E0E4094F0>,
#  'Node 109': <__main__.FederatedNode object at 0x0000022E0E409820>,
#  'Node 11': <__main__.FederatedNode object at 0x0000022E0E3BC9B0>,
#  'Node 110': <__main__.FederatedNode object at 0x0000022E0E409A60>,
#  'Node 111': <__main__.FederatedNode object at 0x0000022E0E409C40>,
#  'Node 112': <__main__.FederatedNode object at 0x0000022E0E409E50>,
#  'Node 113': <__main__.FederatedNode object at 0x0000022E0E40A030>,
#  'Node 114': <__main__.FederatedNode object at 0x0000022E0E40A1B0>,
#  'Node 115': <__main__.FederatedNode object at 0x0000022E0E40A390>,
#  'Node 116': <__main__.FederatedNode object at 0x0000022E0E40A540>,
#  'Node 117': <__main__.FederatedNode object at 0x0000022E0E40A780>,
#  'Node 118': <__main__.FederatedNode object at 0x0000022E0E40A960>,
#  'Node 119': <__main__.FederatedNode object at 0x0000022E0E40AB70>,
#  'Node 12': <__main__.FederatedNode object at 0x0000022E0E3BCF80>,
#  'Node 120': <__main__.FederatedNode object at 0x0000022E0E40ADE0>,
#  'Node 121': <__main__.FederatedNode object at 0x0000022E0E40AF30>,
#  'Node 122': <__main__.FederatedNode object at 0x0000022E0E40B170>,
#  'Node 123': <__main__.FederatedNode object at 0x0000022E0E40B2F0>,
#  'Node 124': <__main__.FederatedNode object at 0x0000022E0E40B560>,
#  'Node 125': <__main__.FederatedNode object at 0x0000022E0E40B6E0>,
#  'Node 126': <__main__.FederatedNode object at 0x0000022E0E40B920>,
#  'Node 127': <__main__.FederatedNode object at 0x0000022E0E40BBC0>,
#  'Node 128': <__main__.FederatedNode object at 0x0000022E0E40BEC0>,
#  'Node 129': <__main__.FederatedNode object at 0x0000022E0E40C050>,
#  'Node 13': <__main__.FederatedNode object at 0x0000022E0E3BC830>,
#  'Node 130': <__main__.FederatedNode object at 0x0000022E0E40C320>,
#  'Node 131': <__main__.FederatedNode object at 0x0000022E0E40C560>,
#  'Node 132': <__main__.FederatedNode object at 0x0000022E0E40C7D0>,
#  'Node 133': <__main__.FederatedNode object at 0x0000022E0E40C9E0>,
#  'Node 134': <__main__.FederatedNode object at 0x0000022E0E40CBC0>,
#  'Node 135': <__main__.FederatedNode object at 0x0000022E0E40CD40>,
#  'Node 136': <__main__.FederatedNode object at 0x0000022E0E40CF50>,
#  'Node 137': <__main__.FederatedNode object at 0x0000022E0E40D130>,
#  'Node 138': <__main__.FederatedNode object at 0x0000022E0E40D370>,
#  'Node 139': <__main__.FederatedNode object at 0x0000022E0E40D4F0>,
#  'Node 14': <__main__.FederatedNode object at 0x0000022E0E3BC1A0>,
#  'Node 140': <__main__.FederatedNode object at 0x0000022E0E40D700>,
#  'Node 141': <__main__.FederatedNode object at 0x0000022E0E40D8B0>,
#  'Node 142': <__main__.FederatedNode object at 0x0000022E0E40DBB0>,
#  'Node 143': <__main__.FederatedNode object at 0x0000022E0E40DDF0>,
#  'Node 144': <__main__.FederatedNode object at 0x0000022E0E40E090>,
#  'Node 145': <__main__.FederatedNode object at 0x0000022E0E40E2A0>,
#  'Node 146': <__main__.FederatedNode object at 0x0000022E0E40E480>,
#  'Node 147': <__main__.FederatedNode object at 0x0000022E0E40E660>,
#  'Node 148': <__main__.FederatedNode object at 0x0000022E0E40E7B0>,
#  'Node 149': <__main__.FederatedNode object at 0x0000022E0E40EA50>,
#  'Node 15': <__main__.FederatedNode object at 0x0000022E0E3BC3E0>,
#  'Node 150': <__main__.FederatedNode object at 0x0000022E0E40EC30>,
#  'Node 151': <__main__.FederatedNode object at 0x0000022E0E40EE70>,
#  'Node 152': <__main__.FederatedNode object at 0x0000022E0E40F0B0>,
#  'Node 153': <__main__.FederatedNode object at 0x0000022E0E40F2F0>,
#  'Node 154': <__main__.FederatedNode object at 0x0000022E0E40F470>,
#  'Node 155': <__main__.FederatedNode object at 0x0000022E0E40F6B0>,
#  'Node 156': <__main__.FederatedNode object at 0x0000022E0E40F8C0>,
#  'Node 157': <__main__.FederatedNode object at 0x0000022E0E40FAD0>,
#  'Node 158': <__main__.FederatedNode object at 0x0000022E0E40FCB0>,
#  'Node 159': <__main__.FederatedNode object at 0x0000022E0E40FEF0>,
#  'Node 16': <__main__.FederatedNode object at 0x0000022E0E3BC8F0>,
#  'Node 17': <__main__.FederatedNode object at 0x0000022E0E3BD1C0>,
#  'Node 18': <__main__.FederatedNode object at 0x0000022E0E3BD400>,
#  'Node 19': <__main__.FederatedNode object at 0x0000022E0E3BD430>,
#  'Node 2': <__main__.FederatedNode object at 0x0000022E0E3501A0>,
#  'Node 20': <__main__.FederatedNode object at 0x0000022E0E3BCF20>,
#  'Node 21': <__main__.FederatedNode object at 0x0000022E0E3BD820>,
#  'Node 22': <__main__.FederatedNode object at 0x0000022E0E3BD9A0>,
#  'Node 23': <__main__.FederatedNode object at 0x0000022E0E3BDF70>,
#  'Node 24': <__main__.FederatedNode object at 0x0000022E0E3BE1B0>,
#  'Node 25': <__main__.FederatedNode object at 0x0000022E0E3BE1E0>,
#  'Node 26': <__main__.FederatedNode object at 0x0000022E0E3BE2D0>,
#  'Node 27': <__main__.FederatedNode object at 0x0000022E0E3BE720>,
#  'Node 28': <__main__.FederatedNode object at 0x0000022E0E3BE8A0>,
#  'Node 29': <__main__.FederatedNode object at 0x0000022E0E3BECC0>,
#  'Node 3': <__main__.FederatedNode object at 0x0000022E0E353200>,
#  'Node 30': <__main__.FederatedNode object at 0x0000022E0E3BEED0>,
#  'Node 31': <__main__.FederatedNode object at 0x0000022E0E3BEF90>,
#  'Node 32': <__main__.FederatedNode object at 0x0000022E0E3BF0E0>,
#  'Node 33': <__main__.FederatedNode object at 0x0000022E0E3BF680>,
#  'Node 34': <__main__.FederatedNode object at 0x0000022E0E3BFBF0>,
#  'Node 35': <__main__.FederatedNode object at 0x0000022E0E3BFFB0>,
#  'Node 36': <__main__.FederatedNode object at 0x0000022E0C0290A0>,
#  'Node 37': <__main__.FederatedNode object at 0x0000022E0E299280>,
#  'Node 38': <__main__.FederatedNode object at 0x0000022E0E299100>,
#  'Node 39': <__main__.FederatedNode object at 0x0000022E0E2980B0>,
#  'Node 4': <__main__.FederatedNode object at 0x0000022E0C1102F0>,
#  'Node 40': <__main__.FederatedNode object at 0x0000022E0E299D00>,
#  'Node 41': <__main__.FederatedNode object at 0x0000022E0E299250>,
#  'Node 42': <__main__.FederatedNode object at 0x0000022E0E29B0E0>,
#  'Node 43': <__main__.FederatedNode object at 0x0000022E0E299730>,
#  'Node 44': <__main__.FederatedNode object at 0x0000022E0E3960F0>,
#  'Node 45': <__main__.FederatedNode object at 0x0000022E0E394380>,
#  'Node 46': <__main__.FederatedNode object at 0x0000022E0E394950>,
#  'Node 47': <__main__.FederatedNode object at 0x0000022E0E3947A0>,
#  'Node 48': <__main__.FederatedNode object at 0x0000022E0E394890>,
#  'Node 49': <__main__.FederatedNode object at 0x0000022E0E395E20>,
#  'Node 5': <__main__.FederatedNode object at 0x0000022E0C1008C0>,
#  'Node 50': <__main__.FederatedNode object at 0x0000022E0E396240>,
#  'Node 51': <__main__.FederatedNode object at 0x0000022E0E394F80>,
#  'Node 52': <__main__.FederatedNode object at 0x0000022E0E394D10>,
#  'Node 53': <__main__.FederatedNode object at 0x0000022E0E394E30>,
#  'Node 54': <__main__.FederatedNode object at 0x0000022E0E3951C0>,
#  'Node 55': <__main__.FederatedNode object at 0x0000022E0E395370>,
#  'Node 56': <__main__.FederatedNode object at 0x0000022E0E395910>,
#  'Node 57': <__main__.FederatedNode object at 0x0000022E0E395310>,
#  'Node 58': <__main__.FederatedNode object at 0x0000022E0E396810>,
#  'Node 59': <__main__.FederatedNode object at 0x0000022E0E3961B0>,
#  'Node 6': <__main__.FederatedNode object at 0x0000022E0C1017F0>,
#  'Node 60': <__main__.FederatedNode object at 0x0000022E0E3968D0>,
#  'Node 61': <__main__.FederatedNode object at 0x0000022E0E396B40>,
#  'Node 62': <__main__.FederatedNode object at 0x0000022E0E396D20>,
#  'Node 63': <__main__.FederatedNode object at 0x0000022E0E397440>,
#  'Node 64': <__main__.FederatedNode object at 0x0000022E0E396900>,
#  'Node 65': <__main__.FederatedNode object at 0x0000022E0E397710>,
#  'Node 66': <__main__.FederatedNode object at 0x0000022E0E397830>,
#  'Node 67': <__main__.FederatedNode object at 0x0000022E0E397B30>,
#  'Node 68': <__main__.FederatedNode object at 0x0000022E0E397C50>,
#  'Node 69': <__main__.FederatedNode object at 0x0000022E0E397F80>,
#  'Node 7': <__main__.FederatedNode object at 0x0000022E0E3BE540>,
#  'Node 70': <__main__.FederatedNode object at 0x0000022E0E3C0080>,
#  'Node 71': <__main__.FederatedNode object at 0x0000022E0E3C0260>,
#  'Node 72': <__main__.FederatedNode object at 0x0000022E0E3C0560>,
#  'Node 73': <__main__.FederatedNode object at 0x0000022E0E3C0680>,
#  'Node 74': <__main__.FederatedNode object at 0x0000022E0E3C0920>,
#  'Node 75': <__main__.FederatedNode object at 0x0000022E0E3C09E0>,
#  'Node 76': <__main__.FederatedNode object at 0x0000022E0E3C1160>,
#  'Node 77': <__main__.FederatedNode object at 0x0000022E0E3C12E0>,
#  'Node 78': <__main__.FederatedNode object at 0x0000022E0E3C0B30>,
#  'Node 79': <__main__.FederatedNode object at 0x0000022E0E3C14C0>,
#  'Node 8': <__main__.FederatedNode object at 0x0000022E0E3BF380>,
#  'Node 80': <__main__.FederatedNode object at 0x0000022E0E3C15E0>,
#  'Node 81': <__main__.FederatedNode object at 0x0000022E0E3C1F40>,
#  'Node 82': <__main__.FederatedNode object at 0x0000022E0E3C16D0>,
#  'Node 83': <__main__.FederatedNode object at 0x0000022E0E3C2240>,
#  'Node 84': <__main__.FederatedNode object at 0x0000022E0E3C1BB0>,
#  'Node 85': <__main__.FederatedNode object at 0x0000022E0E3C1DC0>,
#  'Node 86': <__main__.FederatedNode object at 0x0000022E0E3C1F10>,
#  'Node 87': <__main__.FederatedNode object at 0x0000022E0E3C2780>,
#  'Node 88': <__main__.FederatedNode object at 0x0000022E0E3C2A50>,
#  'Node 89': <__main__.FederatedNode object at 0x0000022E0E3C2600>,
#  'Node 9': <__main__.FederatedNode object at 0x0000022E0E3BF5F0>,
#  'Node 90': <__main__.FederatedNode object at 0x0000022E0E3C2AB0>,
#  'Node 91': <__main__.FederatedNode object at 0x0000022E0E3C2DE0>,
#  'Node 92': <__main__.FederatedNode object at 0x0000022E0E3C32C0>,
#  'Node 93': <__main__.FederatedNode object at 0x0000022E0E3C2ED0>,
#  'Node 94': <__main__.FederatedNode object at 0x0000022E0E3C38C0>,
#  'Node 95': <__main__.FederatedNode object at 0x0000022E0E3C3A70>,
#  'Node 96': <__main__.FederatedNode object at 0x0000022E0E3C3C50>,
#  'Node 97': <__main__.FederatedNode object at 0x0000022E0E3C3FE0>,
#  'Node 98': <__main__.FederatedNode object at 0x0000022E0E3C3EC0>,
#  'Node 99': <__main__.FederatedNode object at 0x0000022E0E4080E0>}

# %% [markdown]
# ##### Running the simulation

# %%
sys.setrecursionlimit(10_000)

for cycle in tqdm(range(chosen_scale['cycles']), desc= "Running Simulation: " + str(chosen_scale["cycles"] ) + " Cycles in total", position=0):
        for request in tqdm(range(chosen_scale["requests"]), desc= "Current Cycle: " + str(cycle + 1), position=1):
                node = choice(list(nodes.values()))
                saveCycleData("Cycle: " + str(cycle + 1), node.issue_request(choice(list(nodes.keys()))))
# Out:
# Current Cycle: 1: 100%|██████████| 300/300 [01:02<00:00,  4.80it/s]0<?, ?it/s]
# Running Simulation: 50 Cycles in total:   2%|▏         | 1/50 [01:02<51:03, 62.52s/it]

# %% [markdown]
# ### Simulation Results

# %% [markdown]
# ##### Request Delay and Information Propagation

# %%
request_dataset = pd.DataFrame(request_data)

request_dataset
# Out:
#                               request_id request_client  request_size  \
# 0   c292592c-5f82-442f-83e2-56407d06fc74        Node 30       1066.06
# 1   57466cc0-e65d-41b1-9e04-c8a26ceab2be        Node 22       1220.45
# 2   f2878942-3e5b-4dc9-a3a8-fff8aed9f056        Node 34       1071.97
# 3   5161679d-deec-4012-90d6-c2dd92781f9f         Node 1        798.51
# 4   d397b3fb-730c-408f-be71-4498e68805eb        Node 26       1121.89
# ..                                   ...            ...           ...
# 95  d996d770-19e6-43fa-bcf7-a73b178c4988         Node 1       1216.62
# 96  599851ea-550b-43c3-b2a5-7c766358ccd4        Node 16       1234.51
# 97  7f62e7ea-162a-4a4c-86fb-a1f78671edd0        Node 45       1220.45
# 98  f3b0b3d1-a755-488d-aefe-9c80e2c9f739        Node 46       1291.54
# 99  7afb4919-078f-4578-a16a-9098a576ff2a        Node 26        614.17
#
#     request_delay  request_diserialization  request_serialization  \
# 0        0.248649                   0.1406               0.232869
# 1        0.138861                   0.2079               0.040454
# 2        0.302879                   0.1841               0.083824
# 3        0.295897                   0.1236               0.162007
# 4        0.209114                   0.2264               0.290465
# ..            ...                      ...                    ...
# 95       0.155776                   0.1841               0.093063
# 96       0.315344                   0.2742               0.206270
# 97       0.345473                   0.2264               0.205503
# 98       0.246020                   0.1769               0.134478
# 99       0.263711                   0.2213               0.054227
#
#    request_status
# 0         process
# 1          denied
# 2          denied
# 3          denied
# 4         process
# ..            ...
# 95        process
# 96         denied
# 97        process
# 98         denied
# 99         denied
#
# [100 rows x 7 columns]

# %%
request_delays = request_dataset[["request_delay", "request_diserialization", "request_serialization"]]

request_delays
# Out:
#     request_delay  request_diserialization  request_serialization
# 0        0.248649                   0.1406               0.232869
# 1        0.138861                   0.2079               0.040454
# 2        0.302879                   0.1841               0.083824
# 3        0.295897                   0.1236               0.162007
# 4        0.209114                   0.2264               0.290465
# ..            ...                      ...                    ...
# 95       0.155776                   0.1841               0.093063
# 96       0.315344                   0.2742               0.206270
# 97       0.345473                   0.2264               0.205503
# 98       0.246020                   0.1769               0.134478
# 99       0.263711                   0.2213               0.054227
#
# [100 rows x 3 columns]

# %% [markdown]
# ##### Response Delay Information Propagation

# %%
response_dataset = pd.DataFrame(response_data)

response_dataset
# Out:
#                              response_id response_client  response_size  \
# 0   c292592c-5f82-442f-83e2-56407d06fc74         Node 29        1336.58
# 1   57466cc0-e65d-41b1-9e04-c8a26ceab2be         Node 49         618.25
# 2   f2878942-3e5b-4dc9-a3a8-fff8aed9f056         Node 25        1216.62
# 3   5161679d-deec-4012-90d6-c2dd92781f9f         Node 31        1071.97
# 4   d397b3fb-730c-408f-be71-4498e68805eb         Node 33         727.93
# ..                                   ...             ...            ...
# 95  d996d770-19e6-43fa-bcf7-a73b178c4988         Node 32         991.47
# 96  599851ea-550b-43c3-b2a5-7c766358ccd4         Node 46         614.17
# 97  7f62e7ea-162a-4a4c-86fb-a1f78671edd0         Node 18         681.42
# 98  f3b0b3d1-a755-488d-aefe-9c80e2c9f739         Node 27         749.84
# 99  7afb4919-078f-4578-a16a-9098a576ff2a         Node 47        1234.51
#
#     response_delay  response_diserialization  response_serialization  \
# 0         0.101745                  0.007025                0.191024
# 1         0.254135                  0.091227                0.218711
# 2         0.111923                  0.053977                0.297652
# 3         0.186633                  0.014996                0.183823
# 4         0.303719                  0.025997                0.145658
# ..             ...                       ...                     ...
# 95        0.095178                  0.014999                0.189284
# 96        0.143859                  0.010965                0.408234
# 97        0.171327                  0.029965                0.127026
# 98        0.202397                  0.014035                0.324058
# 99        0.275871                  0.097031                0.200658
#
#    response_status
# 0          process
# 1           denied
# 2           denied
# 3           denied
# 4          process
# ..             ...
# 95         process
# 96          denied
# 97         process
# 98          denied
# 99          denied
#
# [100 rows x 7 columns]

# %%
response_delays = response_dataset[["response_delay", "response_diserialization", "response_serialization"]]

response_delays
# Out:
#     response_delay  response_diserialization  response_serialization
# 0         0.101745                  0.007025                0.191024
# 1         0.254135                  0.091227                0.218711
# 2         0.111923                  0.053977                0.297652
# 3         0.186633                  0.014996                0.183823
# 4         0.303719                  0.025997                0.145658
# ..             ...                       ...                     ...
# 95        0.095178                  0.014999                0.189284
# 96        0.143859                  0.010965                0.408234
# 97        0.171327                  0.029965                0.127026
# 98        0.202397                  0.014035                0.324058
# 99        0.275871                  0.097031                0.200658
#
# [100 rows x 3 columns]

# %%
request_delays.plot.hist(alpha=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ##### Cycle Statistics

# %%
cycle_dataset = pd.DataFrame(cycle_data)
bar_plot_selection = cycle_dataset[['cycle', 'data_delay']]
bar_plot_data = {}


temp : Dict[str, List[float]] = {}

cycle_col_one_list = bar_plot_selection['cycle'].tolist()
cycle_col_two_list  = bar_plot_selection['data_delay'].tolist()

for cycle in tqdm(range(len(cycle_col_one_list))):
    sleep(0.001)
    if cycle_col_one_list[cycle] in temp.keys():
        list_of_floats = temp[cycle_col_one_list[cycle]]
        list_of_floats.append(cycle_col_two_list[cycle])
        temp.update({
            cycle_col_one_list[cycle] : list_of_floats
        })
    else:
        list_of_floats = []
        list_of_floats.append(cycle_col_two_list[cycle])
        temp.update({
            cycle_col_one_list[cycle] : list_of_floats
        })

for cycle, list_of_delays in temp.items():
    avg = round(sum(list_of_delays) / len(list_of_delays),8)
    bar_plot_data.update({
        cycle : avg
    })


plt.figure(figsize=(20,5))
plt.title("Average Cycle Delay", size = 20)
plt.bar(bar_plot_data.keys(), bar_plot_data.values(), width=0.4, color= "#0d9488")
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 554.24it/s]
# <BarContainer object of 10 artists>

# %%
plt.figure(figsize=(20,10))
plt.title("Request propagation", size = 20)
plt.xlabel("Request Serialization")
plt.ylabel("Request De-Serialization")
plt.scatter(request_delays['request_diserialization'], request_delays["request_serialization"] , c="#0d9488", s= 50)
plt.show()
